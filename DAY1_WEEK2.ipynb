# %% [markdown]
# <a href="https://colab.research.google.com/github/AktanM11/AI-OI/blob/main/DAY1_WEEK2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U FlagEmbedding
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.1/866.1 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 69.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.3 MB/s eta 0:00:00
# ...
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18919 sha256=1b5a34ee3ad44ecce25875c9b13e9ec7100636b2d5ccb5752b9ec90d846ad269
#   Stored in directory: /root/.cache/pip/wheels/f6/85/c2/9f0f621def52a1d5db7d29984f81e45f9fb6dfeb1a4eb6e31c
# ...

# %%
from FlagEmbedding import FlagAutoModel

model = FlagAutoModel.from_finetuned('BAAI/bge-m3',
                                      use_fp16=True)
# Out:
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]

# %%
# !pip install sentence-transformers python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 5.3 MB/s eta 0:00:00
# ...

# %%
sentences = [
    "Я купил новый современный автомобиль.",
    "Вчера у меня сломалась старая машина.",

    "Робин Гуд натянул тетиву и выстрелил из лука.",
    "Для приготовления супа нужно мелко нарезать репчатый лук.",

    "Стороны подписали двусторонний договор купли-продажи.",
    "Завтра синоптики обещают дождливую и ветреную погоду."
]

# %%
sentences2 = [
    "автомобиль",
    "машина",

    "лук репчатый",
    "лук боевой",

    "договор",
    "погода"
]

# %%
another_output = model.encode(sentences2)
another_embeddings = another_output['dense_vecs']

# %%
output = model.encode(sentences)
embeddings = output['dense_vecs']

# %%
def cosine_similarity(a, b):
    return sum([a_i * b_i for a_i, b_i in zip(a, b)]) / (
        sum([a_i ** 2 for a_i in a]) ** 0.5 * sum([b_i ** 2 for b_i in b]) ** 0.5)

# %%
from sentence_transformers import util

sim_synonyms1 = util.cos_sim(embeddings[0], embeddings[1])
sim_homonyms1 = util.cos_sim(embeddings[2], embeddings[3])
sim_unrelated1 = util.cos_sim(embeddings[4], embeddings[5])

sim_synonyms = cosine_similarity(embeddings[0], embeddings[1])
sim_homonyms = cosine_similarity(embeddings[2], embeddings[3])
sim_unrelated = cosine_similarity(embeddings[4], embeddings[5])

print(f"Синонимы (вручную): {sim_synonyms:.4f}")
print(f"Синонимы (с библиотеки): {sim_synonyms1.item():.4f}")

print(f"Омонимы (вручную): {sim_homonyms:.4f} ")
print(f"Омонимы (с библиотеки):  {sim_homonyms1.item():.4f}")

print(f"Несвязанные (вручную): {sim_unrelated:.4f} ")
print(f"Несвязанные (с библиотеки): {sim_unrelated1.item():.4f}")
# Out:
# Синонимы (вручную): 0.7218
# Синонимы (с библиотеки): 0.7218
# Омонимы (вручную): 0.3858
# Омонимы (с библиотеки):  0.3858
# Несвязанные (вручную): 0.4595
# Несвязанные (с библиотеки): 0.4595

# %%
from sentence_transformers import util

another_sim_synonyms = util.cos_sim(another_embeddings[0], another_embeddings[1])
another_sim_homonyms = util.cos_sim(another_embeddings[2], another_embeddings[3])
another_sim_unrelated = util.cos_sim(another_embeddings[4], another_embeddings[5])

another_sim_synonyms1 = cosine_similarity(another_embeddings[0], another_embeddings[1])
another_sim_homonyms1 = cosine_similarity(another_embeddings[2], another_embeddings[3])
another_sim_unrelated1 = cosine_similarity(another_embeddings[4], another_embeddings[5])

print(f"Синонимы (вручную): {another_sim_synonyms1:.4f}")
print(f"Синонимы (с библиотеки): {another_sim_synonyms.item():.4f}")

print(f"Омонимы (вручную): {another_sim_homonyms1:.4f} ")
print(f"Омонимы (с библиотеки):  {another_sim_homonyms.item():.4f}")

print(f"Несвязанные (вручную): {another_sim_unrelated1:.4f} ")
print(f"Несвязанные (с библиотеки): {another_sim_unrelated.item():.4f}")
# Out:
# Синонимы (вручную): 0.8391
# Синонимы (с библиотеки): 0.8391
# Омонимы (вручную): 0.6892
# Омонимы (с библиотеки):  0.6892
# Несвязанные (вручную): 0.5741
# Несвязанные (с библиотеки): 0.5741
