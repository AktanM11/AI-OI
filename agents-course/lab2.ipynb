# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=InferenceClientModel())

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="Wayne's mansion party music recommendations")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [The Wayne Mansion](https://www.luckysavannah.com/vacation-rentals/wayne-mansion)
# The Wayne Mansion is on one of Savannah's most well-known streets, surrounded by stunning renovated mansions, just
# steps from Forysth Park.
#
# [Wedding Party Entrance Songs to Get the Party Started -
# The](https://mansiononmainstreet.com/wedding-party-entrance-songs-to-get-the-party-started/)
# You can serve delicious food at a gorgeous venue, but the music is what really takes a party from mediocre to
# unforgettable .
#
# [Wayne Foster Music & Entertainment Reviews - Carlsbad, CA -
# 17](https://www.weddingwire.com/reviews/wayne-foster-music-entertainment-carlsbad/588003f73bdc1398.html)
# Wayne Foster is amazing! We had a 7-person band play at our wedding and they were ON FIRE! Instead of taking the
# expected break between sets, the band ...
#
# [Wayne Tree Manor Reviews - Wayne, MI - 28
# Reviews](https://www.weddingwire.com/reviews/wayne-tree-manor-wayne/cc335ebd7347d092.html)
# Wayne Tree Manor is the way to go for any social events! They will work with you and they have a marvellous manager
# by the name of Krista, she is ...
#
# [TYLER PERRY’S ATLANTA MANSION SELLS TO STEVE HARVEY
# &](https://www.spatehiphopnews.com/2020/06/tyler-perrys-atlanta-mansion-sells-to.html)
# Partial to the Atlanta area, his longtime home ... Drillmatic, the new album by The Game, with 31 songs and a who s
# who of well-known musicians on it.
#
# [Lil Wayne Serenaded By Keith Sweat At 40th Birthday
# Celebration](https://www.hotnewhiphop.com/435668-lil-wayne-serenaded-by-keith-sweat-at-40th-birthday-celebration)
# Just returned from Lil Wayne’s 40th birthday party,” Skip ... Music Lil Wayne Puts Miami Mansion On Market For
# $29.5 Million September 27, 2022
#
# [Writing actions as code snippets or JSON blobs - Hugging
# Face](https://huggingface.co/learn/agents-course/unit2/smolagents/tool_calling_agents)
# Calling tool: web_search with arguments: { query : " best music recommendations for a party at Wayne s │ │ mansion
# ...
#
# [Writing actions as code snippets or JSON blobs - Hugging
# Face](https://huggingface.co/learn/agents-course/en/unit2/smolagents/tool_calling_agents)
# Calling tool: web_search with arguments: { query : " best music recommendations for a party at Wayne s │ │ mansion
# ...
#
# [Nicole Kidman drops £65,000 a month to live in Boy
# George's](https://www.dailymail.com/tvshowbiz/article-15072821/Nicole-Kidman-drops-65-000-month-live-Boy-Georges-Ha
# mpstead-mansion.html)
# But the mansion's controversial past doesn't seem to have put off Hollywood actress Nicole Kidman from living
# there.
#
# [Wedding & Event Venues that Recommend Gemini DJs in NY/NJ](https://geminidjs.com/nj-wedding-venues/)
# Gemini DJs offers the latest and greatest in music, lighting, tv’s ... Call us today at 973-686-1003 to schedule
# time to visit our studio in Wayne!
#
# Out: None
# [Step 1: Duration 8.73 seconds| Input tokens: 2,090 | Output tokens: 887]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="best music for mansion party")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Our First Mansion Party | TikTok](https://www.tiktok.com/discover/our-first-mansion-party)
# Discover my unforgettable Mansion Pool Party adventure filled with music and fun!no better place than a mansion
# #mansion #nye #nye2026 #2026 #londonnye Experience Spectacular NYE Parties in a London Mansion. Join us for
# unforgettable NYE parties in stunning London mansions.
#
# [Best of Deep House 2026 Deep Chill Sounds for Relaxation -
# 129...](https://muzbrick.org/search/Best+of+Deep+House+2026+✨+Deep+Chill+Sounds+for+Relaxation)
# The Best Of Vocal Deep House Chill Out Music 2015 (2 Hour Mixed By Regard ) 1.The Best Deep House Retro Mix .
# Musica Tiendas 2018. Music for Shops V77.
#
# [Spotify - Web Player: Music for everyone](https://open.spotify.com/)
# Spotify is a digital music service that gives you access to millions of songs.
#
# [Miami Music - Best Deep House Mix2024 [Vol.2]](https://ok.ru/video/7429053352536)
# It's empty for now, but we will find the best publications soon, and they will appear in this tab. Similar videos.
#
# [Mansion Party - NSP - YouTube](https://www.youtube.com/watch?v=dNoafUU4Ikw)
# About Press Copyright Contact us Creators Advertise Developers Terms Privacy Policy & Safety How...
#
# [The 100 Greatest Albums of All Time: See the Full
# List](https://consequence.net/2022/09/best-albums-all-time-list/)
# To celebrate 15 years in business, we're taking a shot at boiling down all of popular music history into the 100
# greatest albums of all time.
#
# [oldhousedreams.com](https://www.oldhousedreams.com/)
# Ex: GA, NY, WV; St, Dr, Ave. The best way to search is by zip.
#
# [Главная - YouTube](https://www.youtube.com/)
# Смотрите любимые видео, слушайте любимые песни, загружайте собственные ролики и делитесь ими с друзьями, близкими и
# целым миром.
#
# [Google](https://www.google.com/)
# Поиск информации в интернете: веб страницы, картинки, видео и многое другое.
#
# [Sam Stream - Watch Live on Kick](https://kick.com/sam)
# I'm Sam Pepper and I livestream almost every day! I also post content on all my socials. Check them out below.
# Business Enquiries Email: hello@sam.sucks...
#
# Out: None
# [Step 2: Duration 8.75 seconds| Input tokens: 5,114 | Output tokens: 2,110]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Deep House")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Deep House
# [Step 3: Duration 22.69 seconds| Input tokens: 8,829 | Output tokens: 6,408]
# 'Deep House'

# %%
from smolagents import CodeAgent, tool, InferenceClientModel

# Tool to suggest a menu based on the occasion
@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion (str): The type of occasion for the party. Allowed values are:
                        - "casual": Menu for casual party.
                        - "formal": Menu for formal party.
                        - "superhero": Menu for superhero party.
                        - "custom": Custom menu.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

# Alfred, the butler, preparing the menu for the party
agent = CodeAgent(tools=[suggest_menu], model=InferenceClientModel())

# Preparing the menu for the party
agent.run("Prepare a formal menu for the party.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Prepare a formal menu for the party.                                                                            │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   menu = suggest_menu(occasion="formal")
#   final_answer(menu)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 3-course dinner with wine and dessert.
# [Step 1: Duration 3.43 seconds| Input tokens: 2,112 | Output tokens: 398]
# '3-course dinner with wine and dessert.'

# %%
from smolagents import CodeAgent, InferenceClientModel
import numpy as np
import time
import datetime

agent = CodeAgent(tools=[], model=InferenceClientModel(), additional_authorized_imports=['datetime'])

agent.run(
    """
    Alfred needs to prepare for the party. Here are the tasks:
    1. Prepare the drinks - 30 minutes
    2. Decorate the mansion - 60 minutes
    3. Set up the menu - 45 minutes
    4. Prepare the music and playlist - 45 minutes

    If we start right now, at what time will the party be ready?
    """
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred needs to prepare for the party. Here are the tasks:                                                      │
# │     1. Prepare the drinks - 30 minutes                                                                          │
# │     2. Decorate the mansion - 60 minutes                                                                        │
# │     3. Set up the menu - 45 minutes                                                                             │
# │     4. Prepare the music and playlist - 45 minutes                                                              │
# │                                                                                                                 │
# │     If we start right now, at what time will the party be ready?                                                │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   total_minutes = 30 + 60 + 45 + 45
#   hours = total_minutes // 60
#   final_answer(f"{hours} hours")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 3 hours
# [Step 1: Duration 19.68 seconds| Input tokens: 2,111 | Output tokens: 3,943]
# '3 hours'
