# %%
from agents import *

# %%
Router("What is the capital of France?")
# Out:
# RouterOutput(is_agent_needed=False, agent_task='', response='The capital of France is Paris.')

# %%
Router("Сколько будет 657 + 234?")
# Out:
# RouterOutput(is_agent_needed=False, agent_task='', response='891')

# %%
Recurser("Какое расстояние между Бишкеком и Таласом?")
# Out:
# RecurserOutput(is_task_achievable=True, is_task_completed=True, next_task='', final_response='Расстояние между Бишкеком и Таласом примерно:\n- по прямой — около 195–200 км;\n- по автомобильной дороге — около 300–320 км, в зависимости от маршрута.')

# %%
python_executor("Напишите код, который вычисляет сумму чисел от 1 до 100.")
# Out:
# '5050\n'

# %%
Coder("Напишите код, который вычисляет сумму чисел от 1 до 100.")
# Out:
# CoderOutput(code='print(sum(range(1, 101)))')

# %%
Recurser("Какие инструменты тебе доступны?")
# Out:
# RecurserOutput(is_task_achievable=True, is_task_completed=True, next_task='', final_response='Мне доступны такие инструменты:\n\n- Поиск и просмотр веб-страниц для актуальной информации.\n- Специализированные запросы: погода, финансы/котировки, спорт, текущее время.\n- Калькулятор для вычислений.\n- Выполнение Python-кода для анализа данных, расчётов и автоматизации.\n- Просмотр PDF/страниц, поиск по тексту и получение скриншотов PDF.\n\nЯ использую их только когда это нужно для задачи или когда требуется актуальная/проверяемая информация.')

# %%
from loop import Chat

# %%
bot = Chat(Router=Router, Recurser=Recurser)

while True:
    user_input = input("User: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Exiting the chat.")
        break
    response = bot(user_input)
    print(response)
# Out:
# Assistant: Приятно познакомиться, Аскат!
# None
# Assistant: Вас зовут Аскат.
# None
# Assistant: Понял, Аскат, вам 21 год.
# None
# Assistant: Похоже, вы отправили пустое сообщение. Чем могу помочь, Аскат?
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 bot = Chat(Router=Router, Recurser=Recurser)
#       3 while True:
# ----> 4     user_input = input("User: ")
#       5     if user_input.lower() in ["exit", "quit"]:
#       6         print("Exiting the chat.")
#
# File /opt/homebrew/lib/python3.10/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
# ...
